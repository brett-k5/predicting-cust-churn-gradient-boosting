# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import os
import shutil

# %%
# !ls -h
# Out:
# sample_data

# %%
directory = '/content'

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
            print(f"Deleted folder: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted folder: /content/.config
# Deleted folder: /content/sample_data

# %%
# !ls -h

# %%
# Load lightgbm_gpu_acc_shap.py, features_train.parquet, target_train.parquet from project directory
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-b3d0a762-df95-426c-867a-f56d522047a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3d0a762-df95-426c-867a-f56d522047a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load model_utilities.py from src folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-3f81ab27-2010-4a05-84c5-a93b20e7a68d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f81ab27-2010-4a05-84c5-a93b20e7a68d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load grid_search_light.pkl from cv_tuning_results folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-17b76cce-215e-47f3-9a30-1a3f2d16b933" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17b76cce-215e-47f3-9a30-1a3f2d16b933">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %run lightgbm_gpu_acc_shap.py
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Number of positive: 997, number of negative: 2759
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 816
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 19
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# ...
