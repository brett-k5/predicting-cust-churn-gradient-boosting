# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import os
import shutil

# %%
# !ls -h
# Out:
# sample_data

# %%
directory = '/content'

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
            print(f"Deleted folder: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted folder: /content/.config
# Deleted folder: /content/sample_data

# %%
# !ls -h

# %%
# Load catboost_gpy_acc_shap.py, features_train.parquet, target_train.parquet from project directory
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-a6267fd8-f39b-42ff-8ec7-1d65d8eabcbd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6267fd8-f39b-42ff-8ec7-1d65d8eabcbd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load model_utilities.py from src folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-635bda37-d561-4b1d-941e-8515ca3eee19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-635bda37-d561-4b1d-941e-8515ca3eee19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load grid_search_cat.pkl from cv_tuning_results folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-4e662aa5-63d1-40a5-be08-f6577bea065a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4e662aa5-63d1-40a5-be08-f6577bea065a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %run catboost_gpu_acc_shap.py
# Out:
# Default metric period is 5 because AUC is/are not implemented for GPU
# 0:	total: 32.4ms	remaining: 9.69s
# 1:	total: 48.1ms	remaining: 7.16s
# 2:	total: 63.8ms	remaining: 6.32s
# 3:	total: 78.9ms	remaining: 5.84s
# 4:	total: 97.1ms	remaining: 5.73s
# 5:	total: 112ms	remaining: 5.51s
# 6:	total: 127ms	remaining: 5.33s
# 7:	total: 143ms	remaining: 5.21s
# 8:	total: 159ms	remaining: 5.13s
# 9:	total: 174ms	remaining: 5.06s
# 10:	total: 191ms	remaining: 5.02s
# 11:	total: 206ms	remaining: 4.94s
# 12:	total: 222ms	remaining: 4.9s
# 13:	total: 238ms	remaining: 4.85s
# 14:	total: 252ms	remaining: 4.78s
# 15:	total: 265ms	remaining: 4.71s
# 16:	total: 279ms	remaining: 4.65s
# 17:	total: 293ms	remaining: 4.59s
# 18:	total: 307ms	remaining: 4.55s
# 19:	total: 322ms	remaining: 4.5s
# 20:	total: 339ms	remaining: 4.5s
# 21:	total: 353ms	remaining: 4.46s
# 22:	total: 369ms	remaining: 4.44s
# 23:	total: 382ms	remaining: 4.4s
# 24:	total: 396ms	remaining: 4.36s
# 25:	total: 411ms	remaining: 4.33s
# ...
