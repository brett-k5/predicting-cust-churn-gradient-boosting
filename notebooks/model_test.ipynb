# %%
# !pip install catboost
# !pip install --upgrade shap

# %%
from google.colab import files
import os
import shutil
import matplotlib.pyplot as plt

# %%
# !ls -h
# Out:
# model_utils.py

# %%
directory = '/content'

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
            print(f"Deleted folder: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted file: /content/model_utils.py

# %%
# !ls -h

# %%
# Load model_testing.py, features_train.parquet, target_train.parquet, features_test.parquet, target_test.parquet from project directory
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-ce2b0066-2c04-400b-b16f-5ac1bb51bd47" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce2b0066-2c04-400b-b16f-5ac1bb51bd47">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load catboost_optimal_threshold.joblib, lightgbm_optimal_threshold.joblib, and xgboost_optimal_threshold.joblib from cv_tuning_results
# Load grid_search_cat.joblib, grid_search_light.joblib, and grid_search_xgb.joblib from cv_tuning_results
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-c87dd24f-933e-47d9-b1f2-f7a5c1ecf3d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c87dd24f-933e-47d9-b1f2-f7a5c1ecf3d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load model_utilities.py from src folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-6d746944-2cab-499a-ad5a-5e8fea8a9969" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d746944-2cab-499a-ad5a-5e8fea8a9969">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %run model_testing.py
# Out:
# LightGBM version: 4.6.0
# GPU support is enabled for LightGBM.
# Best Model Type: LGBMClassifier
# [LightGBM] [Info] Number of positive: 1495, number of negative: 4139
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 816
# [LightGBM] [Info] Number of data points in the train set: 5634, number of used features: 19
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# ...
