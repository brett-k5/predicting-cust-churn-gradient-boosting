# %%
pip install catboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 7.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
import os
import shutil

# %%
# !ls -h
# Out:
# sample_data

# %%
directory = '/content'

for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
            print(f"Deleted folder: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted folder: /content/.config
# Deleted folder: /content/sample_data

# %%
# !ls -h

# %%
# Load xgboost_gpu_acc_shap.py, features_train.parquet, target_train.parquet from project directory
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-55c64e29-9182-4405-bf6e-8779dbe0ac68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55c64e29-9182-4405-bf6e-8779dbe0ac68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load model_utilities.py from src folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-b9970752-22ea-449d-bb13-b74f02de5ee5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9970752-22ea-449d-bb13-b74f02de5ee5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load grid_search_xgb.joblib from cv_tuning_results folder
uploaded_files = files.upload()
# Out:
#      <input type="file" id="files-ef61c19b-43f9-4152-a00c-81d25d7b960f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef61c19b-43f9-4152-a00c-81d25d7b960f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %run xgboost_gpu_acc_shap.py
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [00:30:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:183: UserWarning: [00:30:33] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:2676: UserWarning: [00:30:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# ...
